# %% [markdown]
# # Classification with HDF5 data
#
# In this example we'll use Caffe to do simple logistic regression on a simple binary dataset, showcasing HDF5DataLayer functionality.

# %%
import os
import h5py
import shutil
import sklearn
import tempfile
import numpy as np
import pandas as pd
import sklearn.datasets
import sklearn.linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X, y = sklearn.datasets.make_classification(
    n_samples=10000, n_features=4, n_redundant=0, n_informative=2, 
    n_clusters_per_class=2, hypercube=False, random_state=0
)

# Split into train and test
X, Xt, y, yt = sklearn.cross_validation.train_test_split(X, y)

# %%
# Visualize sample of the data
ind = np.random.permutation(X.shape[0])[:1000]
df = pd.DataFrame(X[ind])
_ = pd.scatter_matrix(df, figsize=(9, 9), diagonal='kde', marker='o', s=40, alpha=.4, c=y[ind])

# %%
# Train and test the scikit-learn SGD logistic regression.
clf = sklearn.linear_model.SGDClassifier(
    loss='log', n_iter=1000, penalty='l2', alpha=1e-3, class_weight='auto')

clf.fit(X, y)
yt_pred = clf.predict(Xt)
print('Accuracy: {:.3f}'.format(sklearn.metrics.accuracy_score(yt, yt_pred)))
# Out:
# Accuracy: 0.761

# %%
# Write out the data to HDF5 files in a temp directory.
# This file is assumed to be caffe_root/examples/hdf5_classification.ipynb
dirname = os.path.abspath('./hdf5_classification/data')
if not os.path.exists(dirname):
    os.makedirs(dirname)

train_filename = os.path.join(dirname, 'train.h5')
test_filename = os.path.join(dirname, 'test.h5')

# HDF5DataLayer source should be a file containing a list of HDF5 filenames.
# To show this off, we'll list the same data file twice.
with h5py.File(train_filename, 'w') as f:
    f['data'] = X
    f['label'] = y.astype(np.float32)
with open(os.path.join(dirname, 'train.txt'), 'w') as f:
    f.write(train_filename + '\n')
    f.write(train_filename + '\n')
    
# HDF5 is pretty efficient, but can be further compressed.
comp_kwargs = {'compression': 'gzip', 'compression_opts': 1}
with h5py.File(test_filename, 'w') as f:
    f.create_dataset('data', data=Xt, **comp_kwargs)
    f.create_dataset('label', data=yt.astype(np.float32), **comp_kwargs)
with open(os.path.join(dirname, 'test.txt'), 'w') as f:
    f.write(test_filename + '\n')

# %%
# Run caffe. Scroll down in the output to see the final
# test accuracy, which should be about the same as above.
# !cd .. && ./build/tools/caffe train -solver examples/hdf5_classification/solver.prototxt
# Out:
# I0905 16:19:36.019844  4963 caffe.cpp:90] Starting Optimization
# I0905 16:19:36.020174  4963 solver.cpp:32] Initializing solver from parameters:
# test_iter: 1000
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: CPU
# net: "examples/hdf5_classification/train_val.prototxt"
# I0905 16:19:36.201980  4963 solver.cpp:72] Creating training net from net file: examples/hdf5_classification/train_val.prototxt
# I0905 16:19:36.220800  4963 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I0905 16:19:36.220836  4963 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0905 16:19:36.220897  4963 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TRAIN
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# state {
#   phase: TRAIN
# }
# I0905 16:19:36.221043  4963 net.cpp:67] Creating Layer data
# I0905 16:19:36.221056  4963 net.cpp:356] data -> data
# I0905 16:19:36.221076  4963 net.cpp:356] data -> label
# I0905 16:19:36.221089  4963 net.cpp:96] Setting up data
# I0905 16:19:36.221098  4963 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/train.txt
# I0905 16:19:36.221163  4963 hdf5_data_layer.cpp:69] Number of files: 2
# I0905 16:19:36.221174  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.222323  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.222348  4963 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I0905 16:19:36.222364  4963 net.cpp:103] Top shape: 10 4 1 1 (40)
# I0905 16:19:36.222373  4963 net.cpp:103] Top shape: 10 1 1 1 (10)
# I0905 16:19:36.222385  4963 net.cpp:67] Creating Layer fc1
# I0905 16:19:36.222393  4963 net.cpp:394] fc1 <- data
# I0905 16:19:36.222406  4963 net.cpp:356] fc1 -> fc1
# I0905 16:19:36.222419  4963 net.cpp:96] Setting up fc1
# I0905 16:19:36.222769  4963 net.cpp:103] Top shape: 10 2 1 1 (20)
# I0905 16:19:36.222793  4963 net.cpp:67] Creating Layer loss
# I0905 16:19:36.222802  4963 net.cpp:394] loss <- fc1
# I0905 16:19:36.222810  4963 net.cpp:394] loss <- label
# I0905 16:19:36.222820  4963 net.cpp:356] loss -> loss
# I0905 16:19:36.222829  4963 net.cpp:96] Setting up loss
# I0905 16:19:36.222841  4963 net.cpp:103] Top shape: 1 1 1 1 (1)
# I0905 16:19:36.222847  4963 net.cpp:109]     with loss weight 1
# I0905 16:19:36.222867  4963 net.cpp:170] loss needs backward computation.
# I0905 16:19:36.222874  4963 net.cpp:170] fc1 needs backward computation.
# I0905 16:19:36.222882  4963 net.cpp:172] data does not need backward computation.
# I0905 16:19:36.222888  4963 net.cpp:208] This network produces output loss
# I0905 16:19:36.222898  4963 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I0905 16:19:36.222906  4963 net.cpp:219] Network initialization done.
# I0905 16:19:36.222913  4963 net.cpp:220] Memory required for data: 284
# I0905 16:19:36.223064  4963 solver.cpp:156] Creating test net (#0) specified by net file: examples/hdf5_classification/train_val.prototxt
# I0905 16:19:36.223083  4963 net.cpp:275] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0905 16:19:36.223129  4963 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TEST
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# layers {
#   bottom: "fc1"
#   bottom: "label"
#   top: "accuracy"
#   name: "accuracy"
#   type: ACCURACY
#   include {
#     phase: TEST
#   }
# }
# state {
#   phase: TEST
# }
# I0905 16:19:36.223320  4963 net.cpp:67] Creating Layer data
# I0905 16:19:36.223331  4963 net.cpp:356] data -> data
# I0905 16:19:36.223342  4963 net.cpp:356] data -> label
# I0905 16:19:36.223352  4963 net.cpp:96] Setting up data
# I0905 16:19:36.223361  4963 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/test.txt
# I0905 16:19:36.223381  4963 hdf5_data_layer.cpp:69] Number of files: 1
# I0905 16:19:36.223389  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/test.h5
# I0905 16:19:36.224413  4963 hdf5_data_layer.cpp:49] Successully loaded 2500 rows
# I0905 16:19:36.224437  4963 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I0905 16:19:36.224447  4963 net.cpp:103] Top shape: 10 4 1 1 (40)
# I0905 16:19:36.224454  4963 net.cpp:103] Top shape: 10 1 1 1 (10)
# I0905 16:19:36.224467  4963 net.cpp:67] Creating Layer label_data_1_split
# I0905 16:19:36.224473  4963 net.cpp:394] label_data_1_split <- label
# I0905 16:19:36.224483  4963 net.cpp:356] label_data_1_split -> label_data_1_split_0
# I0905 16:19:36.224494  4963 net.cpp:356] label_data_1_split -> label_data_1_split_1
# I0905 16:19:36.224503  4963 net.cpp:96] Setting up label_data_1_split
# I0905 16:19:36.224513  4963 net.cpp:103] Top shape: 10 1 1 1 (10)
# I0905 16:19:36.224519  4963 net.cpp:103] Top shape: 10 1 1 1 (10)
# I0905 16:19:36.224529  4963 net.cpp:67] Creating Layer fc1
# I0905 16:19:36.224536  4963 net.cpp:394] fc1 <- data
# I0905 16:19:36.224546  4963 net.cpp:356] fc1 -> fc1
# I0905 16:19:36.224557  4963 net.cpp:96] Setting up fc1
# I0905 16:19:36.224570  4963 net.cpp:103] Top shape: 10 2 1 1 (20)
# I0905 16:19:36.224583  4963 net.cpp:67] Creating Layer fc1_fc1_0_split
# I0905 16:19:36.224591  4963 net.cpp:394] fc1_fc1_0_split <- fc1
# I0905 16:19:36.224601  4963 net.cpp:356] fc1_fc1_0_split -> fc1_fc1_0_split_0
# I0905 16:19:36.224609  4963 net.cpp:356] fc1_fc1_0_split -> fc1_fc1_0_split_1
# I0905 16:19:36.224619  4963 net.cpp:96] Setting up fc1_fc1_0_split
# I0905 16:19:36.224627  4963 net.cpp:103] Top shape: 10 2 1 1 (20)
# I0905 16:19:36.224633  4963 net.cpp:103] Top shape: 10 2 1 1 (20)
# I0905 16:19:36.224643  4963 net.cpp:67] Creating Layer loss
# I0905 16:19:36.224650  4963 net.cpp:394] loss <- fc1_fc1_0_split_0
# I0905 16:19:36.224658  4963 net.cpp:394] loss <- label_data_1_split_0
# I0905 16:19:36.224668  4963 net.cpp:356] loss -> loss
# I0905 16:19:36.224676  4963 net.cpp:96] Setting up loss
# I0905 16:19:36.224686  4963 net.cpp:103] Top shape: 1 1 1 1 (1)
# I0905 16:19:36.224694  4963 net.cpp:109]     with loss weight 1
# I0905 16:19:36.224704  4963 net.cpp:67] Creating Layer accuracy
# I0905 16:19:36.224711  4963 net.cpp:394] accuracy <- fc1_fc1_0_split_1
# I0905 16:19:36.224720  4963 net.cpp:394] accuracy <- label_data_1_split_1
# I0905 16:19:36.224728  4963 net.cpp:356] accuracy -> accuracy
# I0905 16:19:36.224738  4963 net.cpp:96] Setting up accuracy
# I0905 16:19:36.224746  4963 net.cpp:103] Top shape: 1 1 1 1 (1)
# I0905 16:19:36.224753  4963 net.cpp:172] accuracy does not need backward computation.
# I0905 16:19:36.224761  4963 net.cpp:170] loss needs backward computation.
# I0905 16:19:36.224768  4963 net.cpp:170] fc1_fc1_0_split needs backward computation.
# I0905 16:19:36.224776  4963 net.cpp:170] fc1 needs backward computation.
# I0905 16:19:36.224782  4963 net.cpp:172] label_data_1_split does not need backward computation.
# I0905 16:19:36.224791  4963 net.cpp:172] data does not need backward computation.
# I0905 16:19:36.224797  4963 net.cpp:208] This network produces output accuracy
# I0905 16:19:36.224817  4963 net.cpp:208] This network produces output loss
# I0905 16:19:36.224829  4963 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I0905 16:19:36.224838  4963 net.cpp:219] Network initialization done.
# I0905 16:19:36.224844  4963 net.cpp:220] Memory required for data: 528
# I0905 16:19:36.224867  4963 solver.cpp:46] Solver scaffolding done.
# I0905 16:19:36.224877  4963 solver.cpp:165] Solving LogisticRegressionNet
# I0905 16:19:36.224890  4963 solver.cpp:251] Iteration 0, Testing net (#0)
# I0905 16:19:36.271775  4963 solver.cpp:302]     Test net output #0: accuracy = 0.3508
# I0905 16:19:36.271821  4963 solver.cpp:302]     Test net output #1: loss = 0.696308 (* 1 = 0.696308 loss)
# I0905 16:19:36.277894  4963 solver.cpp:195] Iteration 0, loss = 0.697882
# I0905 16:19:36.277911  4963 solver.cpp:210]     Train net output #0: loss = 0.697882 (* 1 = 0.697882 loss)
# I0905 16:19:36.277930  4963 solver.cpp:406] Iteration 0, lr = 0.01
# I0905 16:19:36.287329  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.287794  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.291009  4963 solver.cpp:251] Iteration 1000, Testing net (#0)
# I0905 16:19:36.301214  4963 solver.cpp:302]     Test net output #0: accuracy = 0.706
# I0905 16:19:36.301254  4963 solver.cpp:302]     Test net output #1: loss = 0.598815 (* 1 = 0.598815 loss)
# I0905 16:19:36.302435  4963 solver.cpp:195] Iteration 1000, loss = 0.792049
# I0905 16:19:36.302450  4963 solver.cpp:210]     Train net output #0: loss = 0.792049 (* 1 = 0.792049 loss)
# I0905 16:19:36.302461  4963 solver.cpp:406] Iteration 1000, lr = 0.01
# I0905 16:19:36.308325  4963 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:36.308342  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.308771  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.318832  4963 solver.cpp:251] Iteration 2000, Testing net (#0)
# I0905 16:19:36.329114  4963 solver.cpp:302]     Test net output #0: accuracy = 0.7256
# I0905 16:19:36.329150  4963 solver.cpp:302]     Test net output #1: loss = 0.599137 (* 1 = 0.599137 loss)
# I0905 16:19:36.329263  4963 solver.cpp:195] Iteration 2000, loss = 0.624116
# I0905 16:19:36.329277  4963 solver.cpp:210]     Train net output #0: loss = 0.624116 (* 1 = 0.624116 loss)
# I0905 16:19:36.329288  4963 solver.cpp:406] Iteration 2000, lr = 0.01
# I0905 16:19:36.339908  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.340355  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.371665  4963 solver.cpp:251] Iteration 3000, Testing net (#0)
# I0905 16:19:36.381944  4963 solver.cpp:302]     Test net output #0: accuracy = 0.763601
# I0905 16:19:36.381969  4963 solver.cpp:302]     Test net output #1: loss = 0.594242 (* 1 = 0.594242 loss)
# I0905 16:19:36.381978  4963 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:36.381986  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.382428  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.382457  4963 solver.cpp:195] Iteration 3000, loss = 0.341659
# I0905 16:19:36.382472  4963 solver.cpp:210]     Train net output #0: loss = 0.341659 (* 1 = 0.341659 loss)
# I0905 16:19:36.382483  4963 solver.cpp:406] Iteration 3000, lr = 0.01
# I0905 16:19:36.403834  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.404284  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.412317  4963 solver.cpp:251] Iteration 4000, Testing net (#0)
# I0905 16:19:36.424984  4963 solver.cpp:302]     Test net output #0: accuracy = 0.706
# I0905 16:19:36.425025  4963 solver.cpp:302]     Test net output #1: loss = 0.598815 (* 1 = 0.598815 loss)
# I0905 16:19:36.434535  4963 solver.cpp:195] Iteration 4000, loss = 0.792049
# I0905 16:19:36.434584  4963 solver.cpp:210]     Train net output #0: loss = 0.792049 (* 1 = 0.792049 loss)
# I0905 16:19:36.434597  4963 solver.cpp:406] Iteration 4000, lr = 0.01
# I0905 16:19:36.441884  4963 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:36.441900  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.442345  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.458966  4963 solver.cpp:251] Iteration 5000, Testing net (#0)
# I0905 16:19:36.469528  4963 solver.cpp:302]     Test net output #0: accuracy = 0.7256
# I0905 16:19:36.469569  4963 solver.cpp:302]     Test net output #1: loss = 0.599137 (* 1 = 0.599137 loss)
# I0905 16:19:36.469596  4963 solver.cpp:195] Iteration 5000, loss = 0.624116
# I0905 16:19:36.469610  4963 solver.cpp:210]     Train net output #0: loss = 0.624116 (* 1 = 0.624116 loss)
# I0905 16:19:36.469620  4963 solver.cpp:406] Iteration 5000, lr = 0.001
# I0905 16:19:36.472503  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.472967  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.488302  4963 solver.cpp:251] Iteration 6000, Testing net (#0)
# I0905 16:19:36.498836  4963 solver.cpp:302]     Test net output #0: accuracy = 0.7628
# I0905 16:19:36.498865  4963 solver.cpp:302]     Test net output #1: loss = 0.592759 (* 1 = 0.592759 loss)
# I0905 16:19:36.498875  4963 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:36.498883  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.499321  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.499356  4963 solver.cpp:195] Iteration 6000, loss = 0.361885
# I0905 16:19:36.499371  4963 solver.cpp:210]     Train net output #0: loss = 0.361885 (* 1 = 0.361885 loss)
# I0905 16:19:36.499382  4963 solver.cpp:406] Iteration 6000, lr = 0.001
# I0905 16:19:36.512547  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.513048  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.517030  4963 solver.cpp:251] Iteration 7000, Testing net (#0)
# I0905 16:19:36.527355  4963 solver.cpp:302]     Test net output #0: accuracy = 0.7612
# I0905 16:19:36.527390  4963 solver.cpp:302]     Test net output #1: loss = 0.592419 (* 1 = 0.592419 loss)
# I0905 16:19:36.527415  4963 solver.cpp:195] Iteration 7000, loss = 0.755732
# I0905 16:19:36.527427  4963 solver.cpp:210]     Train net output #0: loss = 0.755732 (* 1 = 0.755732 loss)
# I0905 16:19:36.527437  4963 solver.cpp:406] Iteration 7000, lr = 0.001
# I0905 16:19:36.533399  4963 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:36.533418  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.533792  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.539562  4963 solver.cpp:251] Iteration 8000, Testing net (#0)
# I0905 16:19:36.549819  4963 solver.cpp:302]     Test net output #0: accuracy = 0.76
# I0905 16:19:36.549850  4963 solver.cpp:302]     Test net output #1: loss = 0.592632 (* 1 = 0.592632 loss)
# I0905 16:19:36.552502  4963 solver.cpp:195] Iteration 8000, loss = 0.629585
# I0905 16:19:36.552518  4963 solver.cpp:210]     Train net output #0: loss = 0.629585 (* 1 = 0.629585 loss)
# I0905 16:19:36.552528  4963 solver.cpp:406] Iteration 8000, lr = 0.001
# I0905 16:19:36.567021  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.567497  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.575914  4963 solver.cpp:251] Iteration 9000, Testing net (#0)
# I0905 16:19:36.589994  4963 solver.cpp:302]     Test net output #0: accuracy = 0.766001
# I0905 16:19:36.590054  4963 solver.cpp:302]     Test net output #1: loss = 0.592769 (* 1 = 0.592769 loss)
# I0905 16:19:36.590096  4963 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:36.590104  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.590550  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.590582  4963 solver.cpp:195] Iteration 9000, loss = 0.361625
# I0905 16:19:36.590597  4963 solver.cpp:210]     Train net output #0: loss = 0.361625 (* 1 = 0.361625 loss)
# I0905 16:19:36.590608  4963 solver.cpp:406] Iteration 9000, lr = 0.001
# I0905 16:19:36.611474  4963 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:36.611922  4963 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:36.614773  4963 solver.cpp:320] Snapshotting to examples/hdf5_classification/data/train_iter_10000.caffemodel
# I0905 16:19:36.614881  4963 solver.cpp:327] Snapshotting solver state to examples/hdf5_classification/data/train_iter_10000.caffemodel.solverstate
# I0905 16:19:36.614936  4963 solver.cpp:232] Iteration 10000, loss = 0.75589
# I0905 16:19:36.614954  4963 solver.cpp:251] Iteration 10000, Testing net (#0)
# I0905 16:19:36.625311  4963 solver.cpp:302]     Test net output #0: accuracy = 0.762
# I0905 16:19:36.625341  4963 solver.cpp:302]     Test net output #1: loss = 0.592427 (* 1 = 0.592427 loss)
# I0905 16:19:36.625351  4963 solver.cpp:237] Optimization Done.
# I0905 16:19:36.625358  4963 caffe.cpp:114] Optimization Done.

# %% [markdown]
# If you look at the `train_val.prototxt`, you'll see that it's simple logistic regression.
# We can make it a little more advanced by introducing a non-linearity between weights that take the input and weights that give the output -- now we have a two-layer neural network.
# That network is given in `train_val2.prototxt`, and that's the only change made in `solver2.prototxt` which we will now use.
#
# The final accuracy of the network we'll train below should be higher than for the network above!

# %%
# !cd .. && ./build/tools/caffe train -solver examples/hdf5_classification/solver2.prototxt
# Out:
# I0905 16:19:58.728597  4972 caffe.cpp:90] Starting Optimization
# I0905 16:19:58.729110  4972 solver.cpp:32] Initializing solver from parameters:
# test_iter: 1000
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: CPU
# net: "examples/hdf5_classification/train_val2.prototxt"
# I0905 16:19:58.925707  4972 solver.cpp:72] Creating training net from net file: examples/hdf5_classification/train_val2.prototxt
# I0905 16:19:58.926225  4972 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I0905 16:19:58.926250  4972 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0905 16:19:58.926323  4972 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TRAIN
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   top: "fc1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "fc1"
#   top: "fc2"
#   name: "fc2"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc2"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# state {
#   phase: TRAIN
# }
# I0905 16:19:58.926559  4972 net.cpp:67] Creating Layer data
# I0905 16:19:58.926584  4972 net.cpp:356] data -> data
# I0905 16:19:58.926622  4972 net.cpp:356] data -> label
# I0905 16:19:58.926650  4972 net.cpp:96] Setting up data
# I0905 16:19:58.926668  4972 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/train.txt
# I0905 16:19:58.926764  4972 hdf5_data_layer.cpp:69] Number of files: 2
# I0905 16:19:58.926785  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:58.928958  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:58.928993  4972 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I0905 16:19:58.929023  4972 net.cpp:103] Top shape: 10 4 1 1 (40)
# I0905 16:19:58.929040  4972 net.cpp:103] Top shape: 10 1 1 1 (10)
# I0905 16:19:58.929064  4972 net.cpp:67] Creating Layer fc1
# I0905 16:19:58.929078  4972 net.cpp:394] fc1 <- data
# I0905 16:19:58.929105  4972 net.cpp:356] fc1 -> fc1
# I0905 16:19:58.929131  4972 net.cpp:96] Setting up fc1
# I0905 16:19:58.929806  4972 net.cpp:103] Top shape: 10 40 1 1 (400)
# I0905 16:19:58.929851  4972 net.cpp:67] Creating Layer relu1
# I0905 16:19:58.929867  4972 net.cpp:394] relu1 <- fc1
# I0905 16:19:58.929885  4972 net.cpp:345] relu1 -> fc1 (in-place)
# I0905 16:19:58.929904  4972 net.cpp:96] Setting up relu1
# I0905 16:19:58.929919  4972 net.cpp:103] Top shape: 10 40 1 1 (400)
# I0905 16:19:58.929936  4972 net.cpp:67] Creating Layer fc2
# I0905 16:19:58.929950  4972 net.cpp:394] fc2 <- fc1
# I0905 16:19:58.929970  4972 net.cpp:356] fc2 -> fc2
# I0905 16:19:58.929990  4972 net.cpp:96] Setting up fc2
# I0905 16:19:58.930018  4972 net.cpp:103] Top shape: 10 2 1 1 (20)
# I0905 16:19:58.930045  4972 net.cpp:67] Creating Layer loss
# I0905 16:19:58.930060  4972 net.cpp:394] loss <- fc2
# I0905 16:19:58.930078  4972 net.cpp:394] loss <- label
# I0905 16:19:58.930094  4972 net.cpp:356] loss -> loss
# I0905 16:19:58.930115  4972 net.cpp:96] Setting up loss
# I0905 16:19:58.930135  4972 net.cpp:103] Top shape: 1 1 1 1 (1)
# I0905 16:19:58.930150  4972 net.cpp:109]     with loss weight 1
# I0905 16:19:58.930186  4972 net.cpp:170] loss needs backward computation.
# I0905 16:19:58.930244  4972 net.cpp:170] fc2 needs backward computation.
# I0905 16:19:58.930260  4972 net.cpp:170] relu1 needs backward computation.
# I0905 16:19:58.930274  4972 net.cpp:170] fc1 needs backward computation.
# I0905 16:19:58.930289  4972 net.cpp:172] data does not need backward computation.
# I0905 16:19:58.930301  4972 net.cpp:208] This network produces output loss
# I0905 16:19:58.930322  4972 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I0905 16:19:58.930340  4972 net.cpp:219] Network initialization done.
# I0905 16:19:58.930356  4972 net.cpp:220] Memory required for data: 3484
# I0905 16:19:58.930749  4972 solver.cpp:156] Creating test net (#0) specified by net file: examples/hdf5_classification/train_val2.prototxt
# I0905 16:19:58.930795  4972 net.cpp:275] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0905 16:19:58.930918  4972 net.cpp:39] Initializing net from parameters:
# name: "LogisticRegressionNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: HDF5_DATA
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
#   include {
#     phase: TEST
#   }
# }
# layers {
#   bottom: "data"
#   top: "fc1"
#   name: "fc1"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc1"
#   top: "fc1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "fc1"
#   top: "fc2"
#   name: "fc2"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc2"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# layers {
#   bottom: "fc2"
#   bottom: "label"
#   top: "accuracy"
#   name: "accuracy"
#   type: ACCURACY
#   include {
#     phase: TEST
#   }
# }
# state {
#   phase: TEST
# }
# I0905 16:19:58.931395  4972 net.cpp:67] Creating Layer data
# I0905 16:19:58.931416  4972 net.cpp:356] data -> data
# I0905 16:19:58.931439  4972 net.cpp:356] data -> label
# I0905 16:19:58.931460  4972 net.cpp:96] Setting up data
# I0905 16:19:58.931474  4972 hdf5_data_layer.cpp:57] Loading filename from examples/hdf5_classification/data/test.txt
# I0905 16:19:58.931509  4972 hdf5_data_layer.cpp:69] Number of files: 1
# I0905 16:19:58.931525  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/test.h5
# I0905 16:19:58.933234  4972 hdf5_data_layer.cpp:49] Successully loaded 2500 rows
# I0905 16:19:58.933254  4972 hdf5_data_layer.cpp:81] output data size: 10,4,1,1
# I0905 16:19:58.933264  4972 net.cpp:103] Top shape: 10 4 1 1 (40)
# I0905 16:19:58.933271  4972 net.cpp:103] Top shape: 10 1 1 1 (10)
# I0905 16:19:58.933284  4972 net.cpp:67] Creating Layer label_data_1_split
# I0905 16:19:58.933298  4972 net.cpp:394] label_data_1_split <- label
# I0905 16:19:58.933308  4972 net.cpp:356] label_data_1_split -> label_data_1_split_0
# I0905 16:19:58.933321  4972 net.cpp:356] label_data_1_split -> label_data_1_split_1
# I0905 16:19:58.933332  4972 net.cpp:96] Setting up label_data_1_split
# I0905 16:19:58.933341  4972 net.cpp:103] Top shape: 10 1 1 1 (10)
# I0905 16:19:58.933349  4972 net.cpp:103] Top shape: 10 1 1 1 (10)
# I0905 16:19:58.933368  4972 net.cpp:67] Creating Layer fc1
# I0905 16:19:58.933383  4972 net.cpp:394] fc1 <- data
# I0905 16:19:58.933403  4972 net.cpp:356] fc1 -> fc1
# I0905 16:19:58.933424  4972 net.cpp:96] Setting up fc1
# I0905 16:19:58.933460  4972 net.cpp:103] Top shape: 10 40 1 1 (400)
# I0905 16:19:58.933487  4972 net.cpp:67] Creating Layer relu1
# I0905 16:19:58.933502  4972 net.cpp:394] relu1 <- fc1
# I0905 16:19:58.933521  4972 net.cpp:345] relu1 -> fc1 (in-place)
# I0905 16:19:58.933538  4972 net.cpp:96] Setting up relu1
# I0905 16:19:58.933552  4972 net.cpp:103] Top shape: 10 40 1 1 (400)
# I0905 16:19:58.933572  4972 net.cpp:67] Creating Layer fc2
# I0905 16:19:58.933616  4972 net.cpp:394] fc2 <- fc1
# I0905 16:19:58.933637  4972 net.cpp:356] fc2 -> fc2
# I0905 16:19:58.933657  4972 net.cpp:96] Setting up fc2
# I0905 16:19:58.933687  4972 net.cpp:103] Top shape: 10 2 1 1 (20)
# I0905 16:19:58.933712  4972 net.cpp:67] Creating Layer fc2_fc2_0_split
# I0905 16:19:58.933728  4972 net.cpp:394] fc2_fc2_0_split <- fc2
# I0905 16:19:58.933745  4972 net.cpp:356] fc2_fc2_0_split -> fc2_fc2_0_split_0
# I0905 16:19:58.933765  4972 net.cpp:356] fc2_fc2_0_split -> fc2_fc2_0_split_1
# I0905 16:19:58.933785  4972 net.cpp:96] Setting up fc2_fc2_0_split
# I0905 16:19:58.933800  4972 net.cpp:103] Top shape: 10 2 1 1 (20)
# I0905 16:19:58.933815  4972 net.cpp:103] Top shape: 10 2 1 1 (20)
# I0905 16:19:58.933832  4972 net.cpp:67] Creating Layer loss
# I0905 16:19:58.933847  4972 net.cpp:394] loss <- fc2_fc2_0_split_0
# I0905 16:19:58.933863  4972 net.cpp:394] loss <- label_data_1_split_0
# I0905 16:19:58.933882  4972 net.cpp:356] loss -> loss
# I0905 16:19:58.933903  4972 net.cpp:96] Setting up loss
# I0905 16:19:58.933923  4972 net.cpp:103] Top shape: 1 1 1 1 (1)
# I0905 16:19:58.933938  4972 net.cpp:109]     with loss weight 1
# I0905 16:19:58.933962  4972 net.cpp:67] Creating Layer accuracy
# I0905 16:19:58.933976  4972 net.cpp:394] accuracy <- fc2_fc2_0_split_1
# I0905 16:19:58.933994  4972 net.cpp:394] accuracy <- label_data_1_split_1
# I0905 16:19:58.934010  4972 net.cpp:356] accuracy -> accuracy
# I0905 16:19:58.934029  4972 net.cpp:96] Setting up accuracy
# I0905 16:19:58.934044  4972 net.cpp:103] Top shape: 1 1 1 1 (1)
# I0905 16:19:58.934059  4972 net.cpp:172] accuracy does not need backward computation.
# I0905 16:19:58.934073  4972 net.cpp:170] loss needs backward computation.
# I0905 16:19:58.934088  4972 net.cpp:170] fc2_fc2_0_split needs backward computation.
# I0905 16:19:58.934103  4972 net.cpp:170] fc2 needs backward computation.
# I0905 16:19:58.934118  4972 net.cpp:170] relu1 needs backward computation.
# I0905 16:19:58.934131  4972 net.cpp:170] fc1 needs backward computation.
# I0905 16:19:58.934145  4972 net.cpp:172] label_data_1_split does not need backward computation.
# I0905 16:19:58.934160  4972 net.cpp:172] data does not need backward computation.
# I0905 16:19:58.934175  4972 net.cpp:208] This network produces output accuracy
# I0905 16:19:58.934190  4972 net.cpp:208] This network produces output loss
# I0905 16:19:58.934214  4972 net.cpp:467] Collecting Learning Rate and Weight Decay.
# I0905 16:19:58.934231  4972 net.cpp:219] Network initialization done.
# I0905 16:19:58.934245  4972 net.cpp:220] Memory required for data: 3728
# I0905 16:19:58.934303  4972 solver.cpp:46] Solver scaffolding done.
# I0905 16:19:58.934324  4972 solver.cpp:165] Solving LogisticRegressionNet
# I0905 16:19:58.934355  4972 solver.cpp:251] Iteration 0, Testing net (#0)
# I0905 16:19:58.950058  4972 solver.cpp:302]     Test net output #0: accuracy = 0.532
# I0905 16:19:58.950098  4972 solver.cpp:302]     Test net output #1: loss = 0.693141 (* 1 = 0.693141 loss)
# I0905 16:19:58.955122  4972 solver.cpp:195] Iteration 0, loss = 0.693186
# I0905 16:19:58.955173  4972 solver.cpp:210]     Train net output #0: loss = 0.693186 (* 1 = 0.693186 loss)
# I0905 16:19:58.955193  4972 solver.cpp:406] Iteration 0, lr = 0.01
# I0905 16:19:58.978202  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:58.978668  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:58.996508  4972 solver.cpp:251] Iteration 1000, Testing net (#0)
# I0905 16:19:59.011962  4972 solver.cpp:302]     Test net output #0: accuracy = 0.7412
# I0905 16:19:59.011999  4972 solver.cpp:302]     Test net output #1: loss = 0.510781 (* 1 = 0.510781 loss)
# I0905 16:19:59.014307  4972 solver.cpp:195] Iteration 1000, loss = 0.671372
# I0905 16:19:59.014324  4972 solver.cpp:210]     Train net output #0: loss = 0.671372 (* 1 = 0.671372 loss)
# I0905 16:19:59.014334  4972 solver.cpp:406] Iteration 1000, lr = 0.01
# I0905 16:19:59.053768  4972 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:59.053798  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.054262  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.072887  4972 solver.cpp:251] Iteration 2000, Testing net (#0)
# I0905 16:19:59.088371  4972 solver.cpp:302]     Test net output #0: accuracy = 0.803601
# I0905 16:19:59.088407  4972 solver.cpp:302]     Test net output #1: loss = 0.469578 (* 1 = 0.469578 loss)
# I0905 16:19:59.093302  4972 solver.cpp:195] Iteration 2000, loss = 0.370834
# I0905 16:19:59.093327  4972 solver.cpp:210]     Train net output #0: loss = 0.370834 (* 1 = 0.370834 loss)
# I0905 16:19:59.093338  4972 solver.cpp:406] Iteration 2000, lr = 0.01
# I0905 16:19:59.101596  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.102030  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.128252  4972 solver.cpp:251] Iteration 3000, Testing net (#0)
# I0905 16:19:59.143709  4972 solver.cpp:302]     Test net output #0: accuracy = 0.814801
# I0905 16:19:59.145207  4972 solver.cpp:302]     Test net output #1: loss = 0.432905 (* 1 = 0.432905 loss)
# I0905 16:19:59.145222  4972 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:59.145231  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.145695  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.151195  4972 solver.cpp:195] Iteration 3000, loss = 0.200679
# I0905 16:19:59.151237  4972 solver.cpp:210]     Train net output #0: loss = 0.200679 (* 1 = 0.200679 loss)
# I0905 16:19:59.151248  4972 solver.cpp:406] Iteration 3000, lr = 0.01
# I0905 16:19:59.177841  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.178311  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.195956  4972 solver.cpp:251] Iteration 4000, Testing net (#0)
# I0905 16:19:59.216111  4972 solver.cpp:302]     Test net output #0: accuracy = 0.790801
# I0905 16:19:59.216152  4972 solver.cpp:302]     Test net output #1: loss = 0.431082 (* 1 = 0.431082 loss)
# I0905 16:19:59.216195  4972 solver.cpp:195] Iteration 4000, loss = 0.656575
# I0905 16:19:59.216209  4972 solver.cpp:210]     Train net output #0: loss = 0.656575 (* 1 = 0.656575 loss)
# I0905 16:19:59.216220  4972 solver.cpp:406] Iteration 4000, lr = 0.01
# I0905 16:19:59.233414  4972 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:59.233443  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.233891  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.266248  4972 solver.cpp:251] Iteration 5000, Testing net (#0)
# I0905 16:19:59.285704  4972 solver.cpp:302]     Test net output #0: accuracy = 0.816001
# I0905 16:19:59.285742  4972 solver.cpp:302]     Test net output #1: loss = 0.421143 (* 1 = 0.421143 loss)
# I0905 16:19:59.285781  4972 solver.cpp:195] Iteration 5000, loss = 0.38469
# I0905 16:19:59.285796  4972 solver.cpp:210]     Train net output #0: loss = 0.38469 (* 1 = 0.38469 loss)
# I0905 16:19:59.285805  4972 solver.cpp:406] Iteration 5000, lr = 0.001
# I0905 16:19:59.299584  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.300056  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.337667  4972 solver.cpp:251] Iteration 6000, Testing net (#0)
# I0905 16:19:59.353142  4972 solver.cpp:302]     Test net output #0: accuracy = 0.820402
# I0905 16:19:59.353175  4972 solver.cpp:302]     Test net output #1: loss = 0.40937 (* 1 = 0.40937 loss)
# I0905 16:19:59.353185  4972 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:59.353193  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.353629  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.354550  4972 solver.cpp:195] Iteration 6000, loss = 0.176837
# I0905 16:19:59.354603  4972 solver.cpp:210]     Train net output #0: loss = 0.176837 (* 1 = 0.176837 loss)
# I0905 16:19:59.354614  4972 solver.cpp:406] Iteration 6000, lr = 0.001
# I0905 16:19:59.385385  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.385854  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.401273  4972 solver.cpp:251] Iteration 7000, Testing net (#0)
# I0905 16:19:59.416733  4972 solver.cpp:302]     Test net output #0: accuracy = 0.820002
# I0905 16:19:59.418515  4972 solver.cpp:302]     Test net output #1: loss = 0.40734 (* 1 = 0.40734 loss)
# I0905 16:19:59.426548  4972 solver.cpp:195] Iteration 7000, loss = 0.648732
# I0905 16:19:59.426589  4972 solver.cpp:210]     Train net output #0: loss = 0.648732 (* 1 = 0.648732 loss)
# I0905 16:19:59.426601  4972 solver.cpp:406] Iteration 7000, lr = 0.001
# I0905 16:19:59.442756  4972 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:59.442780  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.443227  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.461434  4972 solver.cpp:251] Iteration 8000, Testing net (#0)
# I0905 16:19:59.476825  4972 solver.cpp:302]     Test net output #0: accuracy = 0.819602
# I0905 16:19:59.478200  4972 solver.cpp:302]     Test net output #1: loss = 0.40889 (* 1 = 0.40889 loss)
# I0905 16:19:59.482949  4972 solver.cpp:195] Iteration 8000, loss = 0.356343
# I0905 16:19:59.482991  4972 solver.cpp:210]     Train net output #0: loss = 0.356343 (* 1 = 0.356343 loss)
# I0905 16:19:59.483003  4972 solver.cpp:406] Iteration 8000, lr = 0.001
# I0905 16:19:59.504359  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.504827  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.531766  4972 solver.cpp:251] Iteration 9000, Testing net (#0)
# I0905 16:19:59.547374  4972 solver.cpp:302]     Test net output #0: accuracy = 0.822801
# I0905 16:19:59.547410  4972 solver.cpp:302]     Test net output #1: loss = 0.407038 (* 1 = 0.407038 loss)
# I0905 16:19:59.547420  4972 hdf5_data_layer.cpp:99] looping around to first file
# I0905 16:19:59.547427  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.547870  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.555203  4972 solver.cpp:195] Iteration 9000, loss = 0.177076
# I0905 16:19:59.555243  4972 solver.cpp:210]     Train net output #0: loss = 0.177076 (* 1 = 0.177076 loss)
# I0905 16:19:59.555255  4972 solver.cpp:406] Iteration 9000, lr = 0.001
# I0905 16:19:59.584746  4972 hdf5_data_layer.cpp:29] Loading HDF5 file/home/dmishkin/caffe/examples/hdf5_classification/data/train.h5
# I0905 16:19:59.585217  4972 hdf5_data_layer.cpp:49] Successully loaded 7500 rows
# I0905 16:19:59.611747  4972 solver.cpp:320] Snapshotting to examples/hdf5_classification/data/train_iter_10000.caffemodel
# I0905 16:19:59.611970  4972 solver.cpp:327] Snapshotting solver state to examples/hdf5_classification/data/train_iter_10000.caffemodel.solverstate
# I0905 16:19:59.612048  4972 solver.cpp:232] Iteration 10000, loss = 0.645598
# I0905 16:19:59.612068  4972 solver.cpp:251] Iteration 10000, Testing net (#0)
# I0905 16:19:59.627893  4972 solver.cpp:302]     Test net output #0: accuracy = 0.821601
# I0905 16:19:59.628007  4972 solver.cpp:302]     Test net output #1: loss = 0.404883 (* 1 = 0.404883 loss)
# I0905 16:19:59.628021  4972 solver.cpp:237] Optimization Done.
# I0905 16:19:59.628027  4972 caffe.cpp:114] Optimization Done.

# %%
# Clean up (comment this out if you want to examine the hdf5_classification/data directory).
shutil.rmtree(dirname)
