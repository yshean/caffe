# %% [markdown]
# Here we visualize filters and outputs using the network architecture proposed by Krizhevsky et al. for ImageNet and implemented in `caffe`.
#
# (This page follows DeCAF visualizations originally by Yangqing Jia.)

# %% [markdown]
# First, import required modules and set plotting parameters

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Make sure that caffe is on the python path:
caffe_root = '../'  # this file is expected to be in {caffe_root}/examples
import sys
sys.path.insert(0, caffe_root + 'python')

import caffe

plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# Follow the [instructions](http://caffe.berkeleyvision.org/getting_pretrained_models.html) for getting the pretrained models, load the net, specify test phase and CPU mode, and configure input preprocessing.

# %%
#net = caffe.Classifier(caffe_root + 'examples/imagenet/imagenet_deploy.prototxt',
net = caffe.Classifier(caffe_root + 'examples/imagenet/imagenet_deploy_val2.prototxt',
                       caffe_root + 'examples/imagenet/caffe_reference_imagenet_model')
net.set_phase_test()
net.set_mode_cpu()
# input preprocessing: 'data' is the name of the input blob == net.inputs[0]
net.set_mean('data', caffe_root + 'python/caffe/imagenet/ilsvrc_2012_mean.npy')  # ImageNet mean
net.set_channel_swap('data', (2,1,0))  # the reference model has channels in BGR order instead of RGB
net.set_input_scale('data', 255)  # the reference model operates on images in [0,255] range instead of [0,1]

# %%
im = caffe.io.load_image(caffe_root + 'examples/images/cat.jpg')
data=np.asarray([net.preprocess('data', im)]);

#out['prob'][0].argmax(axis=0)w

# %%
out = net.forward_all(data=np.asarray([net.preprocess('data', im)]))

# %%
# our network takes BGR images, so we need to switch color channels
def showimage(im):
    if im.ndim == 3:
        im = im[:, :, ::-1]
    plt.imshow(im)
    
# take an array of shape (n, height, width) or (n, height, width, channels)
#  and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)
def vis_square(data, padsize=1, padval=0):
    data -= data.min()
    data /= data.max()
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = ((0, n ** 2 - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    
    showimage(data)

# %%
out['prob'];
top_k = out['prob'].flatten().argsort()[-1:-6:-1]

imagenet_labels_filename = caffe_root + 'data/ilsvrc12/synset_words.txt'
try:
    labels = np.loadtxt(imagenet_labels_filename, str, delimiter='\t')
except:
    # !../data/ilsvrc12/get_ilsvrc_aux.sh
    labels = np.loadtxt(imagenet_labels_filename, str, delimiter='\t')

print labels[top_k]
# Out:
# ['n04201297 shoji' 'n04005630 prison, prison house'
#  'n04239074 sliding door'
#  'n02788148 bannister, banister, balustrade, balusters, handrail'
#  'n03388549 four-poster']

# %%
# index four is the center crop
image = net.blobs['data'].data[0].copy()
image -= image.min()
image /= image.max()
showimage(image.transpose(1, 2, 0))

# %%
test1=out['prob'];
test1.shape
test2=test1.copy();
test2[:]=0;
test2[0,34,0,0] = 1;
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-322-940184941b90> in <module>()
# ----> 1 test1=out['prob'];
#       2 test1.shape
#       3 test2=test1.copy();
#       4 test2[:]=0;
#       5 test2[0,34,0,0] = 1;
#
# KeyError: 'prob'

# %%
#out2 = net.forward_backward_all(data=np.asarray([net.preprocess('data', im)])) #blobs=['prob'],prob=diff1)
#out2 = net.forward_backward_all(data=np.asarray([net.preprocess('data', im)]),prob=out['prob']) #blobs=['prob'],prob=diff1)
#feat = out2[1]['data'] ;
#image2 = feat[0];
#image2 -= image2.min();
#image2 /= image2.max();
#showimage(image2.transpose(1, 2, 0))

test1= net.blobs['conv5'].data
image = net.blobs['data'].data[0].copy()
test1.shape


test2=test1.copy();
#test2[:]=0;
#test2[0,0:15,1:7,1:7] = 1;
#out2 = net.backward(prob=test2) #blobs=['prob'],prob=diff1)

out2 = net.backward(conv5=test2) #blobs=['prob'],prob=diff1)
feat = out2['data'] ;
image2 = feat[0];
image3 = image*image2;
image3 -= image3.min();
image3 /= image3.max();
showimage(image3.transpose(1, 2, 0))


#vis_square(feat[0,:], padval=1);

#deproc=net.deprocess('data', out2[1]['data'])
#deproc.shape
#deproc2=deproc;
#deproc2.shape
#feat[0].shape
#plt.imshow(deproc2);#.transpose(1, 2, 0))

# %% [markdown]
# Run a classification pass

# %%
scores = net.predict([caffe.io.load_image(caffe_root + 'examples/images/th-photo3.jpg')])

# %% [markdown]
# The layer features and their shapes (10 is the batch size, corresponding to the the ten subcrops used by Krizhevsky et al.)

# %%
[(k, v.data.shape) for k, v in net.blobs.items()]
# Out:
# [('data', (10, 3, 227, 227)),
#  ('conv1', (10, 96, 55, 55)),
#  ('pool1', (10, 96, 27, 27)),
#  ('norm1', (10, 96, 27, 27)),
#  ('conv2', (10, 256, 27, 27)),
#  ('pool2', (10, 256, 13, 13)),
#  ('norm2', (10, 256, 13, 13)),
#  ('conv3', (10, 384, 13, 13)),
#  ('conv4', (10, 384, 13, 13)),
#  ('conv5', (10, 256, 13, 13)),
#  ('pool5', (10, 256, 6, 6)),
#  ('fc6', (10, 4096, 1, 1)),
#  ('fc7', (10, 4096, 1, 1)),
#  ('fc8', (10, 1000, 1, 1)),
#  ('prob', (10, 1000, 1, 1))]

# %% [markdown]
# The parameters and their shapes (each of these layers also has biases which are omitted here)

# %%
[(k, v[0].data.shape) for k, v in net.params.items()]
# Out:
# [('conv1', (96, 3, 11, 11)),
#  ('conv2', (256, 48, 5, 5)),
#  ('conv3', (384, 256, 3, 3)),
#  ('conv4', (384, 192, 3, 3)),
#  ('conv5', (256, 192, 3, 3)),
#  ('fc6', (1, 1, 4096, 9216)),
#  ('fc7', (1, 1, 4096, 4096)),
#  ('fc8', (1, 1, 1000, 4096))]

# %% [markdown]
# Helper functions for visualization

# %%
# our network takes BGR images, so we need to switch color channels
def showimage(im):
    if im.ndim == 3:
        im = im[:, :, ::-1]
    plt.imshow(im)
    
# take an array of shape (n, height, width) or (n, height, width, channels)
#  and visualize each (height, width) thing in a grid of size approx. sqrt(n) by sqrt(n)
def vis_square(data, padsize=1, padval=0):
    data -= data.min()
    data /= data.max()
    
    # force the number of filters to be square
    n = int(np.ceil(np.sqrt(data.shape[0])))
    padding = ((0, n ** 2 - data.shape[0]), (0, padsize), (0, padsize)) + ((0, 0),) * (data.ndim - 3)
    data = np.pad(data, padding, mode='constant', constant_values=(padval, padval))
    
    # tile the filters into an image
    data = data.reshape((n, n) + data.shape[1:]).transpose((0, 2, 1, 3) + tuple(range(4, data.ndim + 1)))
    data = data.reshape((n * data.shape[1], n * data.shape[3]) + data.shape[4:])
    
    showimage(data)

# %% [markdown]
# The input image

# %%
# index four is the center crop
image = net.blobs['data'].data[0].copy()
image -= image.min()
image /= image.max()
showimage(image.transpose(1, 2, 0))

# %% [markdown]
# The first layer filters, `conv1`

# %%
# the parameters are a list of [weights, biases]
filters = net.params['conv1'][0].data
vis_square(filters.transpose(0, 2, 3, 1))

# %% [markdown]
# The first layer output, `conv1` (rectified responses of the filters above, first 36 only)

# %%
feat = net.blobs['conv1'].data[4, :49]
vis_square(feat, padval=1)

# %% [markdown]
# The second layer filters, `conv2`
#
# There are 256 filters, each of which has dimension 5 x 5 x 48. We show only the first 48 filters, with each channel shown separately, so that each filter is a row.

# %%
filters = net.params['conv2'][0].data
vis_square(filters[:48].reshape(48**2, 5, 5))

# %% [markdown]
# The second layer output, `conv2` (rectified, only the first 36 of 256 channels)

# %%
feat = net.blobs['conv1'].data[4, :36]
vis_square(feat, padval=1)

# %%
feat = net.blobs['conv5'].data[4, :36]
vis_square(feat, padval=0.5)

# %% [markdown]
# The third layer output, `conv3` (rectified, all 384 channels)

# %%
feat = net.blobs['conv3'].data[4]
vis_square(feat, padval=0.5)

# %% [markdown]
# The fourth layer output, `conv4` (rectified, all 384 channels)

# %%
feat = net.blobs['conv4'].data[4]
vis_square(feat, padval=0.5)

# %% [markdown]
# The fifth layer output, `conv5` (rectified, all 256 channels)

# %%
feat = net.blobs['conv5'].data[4]
vis_square(feat, padval=0.5)

# %% [markdown]
# The fifth layer after pooling, `pool5`

# %%
feat = net.blobs['pool5'].data[4]
vis_square(feat, padval=1)

# %% [markdown]
# The first fully connected layer, `fc6` (rectified)
#
# We show the output values and the histogram of the positive values

# %%
feat = net.blobs['fc6'].data[4]
plt.subplot(2, 1, 1)
plt.plot(feat.flat)
plt.subplot(2, 1, 2)
_ = plt.hist(feat.flat[feat.flat > 0], bins=100)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-b58677a73995> in <module>()
# ----> 1 feat = net.blobs['fc6'].data[4]
#       2 plt.subplot(2, 1, 1)
#       3 plt.plot(feat.flat)
#       4 plt.subplot(2, 1, 2)
#       5 _ = plt.hist(feat.flat[feat.flat > 0], bins=100)
#
# IndexError: index 4 is out of bounds for axis 0 with size 1

# %% [markdown]
# The second fully connected layer, `fc7` (rectified)

# %%
feat = net.blobs['fc7'].data[0]
plt.subplot(2, 1, 1)
plt.plot(feat.flat)
plt.subplot(2, 1, 2)
_ = plt.hist(feat.flat[feat.flat > 0], bins=100)

# %% [markdown]
# The final probability output, `prob`

# %%
feat = net.blobs['prob'].data[0]
plt.plot(feat.flat)

# %% [markdown]
# Let's see the top 5 predicted labels.

# %%
imagenet_labels_filename = caffe_root + 'data/ilsvrc12/synset_words.txt'
try:
    labels = np.loadtxt(imagenet_labels_filename, str, delimiter='\t')
except:
    # !../data/ilsvrc12/get_ilsvrc_aux.sh
    labels = np.loadtxt(imagenet_labels_filename, str, delimiter='\t')

# %%
top_k = net.blobs['prob'].data[4].flatten().argsort()[-1:-6:-1]
print labels[top_k]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-108-7c3befed556e> in <module>()
# ----> 1 top_k = net.blobs['prob'].data[4].flatten().argsort()[-1:-6:-1]
#       2 print labels[top_k]
#
# IndexError: index 4 is out of bounds for axis 0 with size 1
